# %%
import pandas as pd

df = pd.read_csv("student.csv")
print(df)
# Out:
#            Name  English  Tamil  Maths  Science  Social_Science  Total Grade
# 0      Student1     50.0   47.0   68.0     91.0             NaN  324.0     D
# 1      Student2     40.0   72.0   94.0     45.0            53.0  304.0     D
# 2      Student3     78.0   61.0   58.0     95.0            75.0  367.0     C
# 3      Student4      NaN   95.0   50.0     80.0            40.0  340.0     D
# 4      Student5     69.0   58.0   54.0     74.0            94.0  349.0     D
# ..          ...      ...    ...    ...      ...             ...    ...   ...
# 295  Student296     68.0   41.0   89.0     64.0            82.0  344.0     D
# 296  Student297     68.0   96.0   82.0     36.0            81.0  363.0     C
# 297  Student298     45.0   47.0   46.0    100.0            57.0  295.0     F
# 298  Student299     97.0  100.0   76.0     97.0            61.0  431.0     B
# 299  Student300     88.0   41.0   64.0     41.0            87.0  321.0     D
#
# [300 rows x 8 columns]

# %%
print(df.head())
# Out:
#        Name  English  Tamil  Maths  Science  Social_Science  Total Grade
# 0  Student1     50.0   47.0   68.0     91.0             NaN  324.0     D
# 1  Student2     40.0   72.0   94.0     45.0            53.0  304.0     D
# 2  Student3     78.0   61.0   58.0     95.0            75.0  367.0     C
# 3  Student4      NaN   95.0   50.0     80.0            40.0  340.0     D
# 4  Student5     69.0   58.0   54.0     74.0            94.0  349.0     D

# %%
print(df.tail())
# Out:
#            Name  English  Tamil  Maths  Science  Social_Science  Total Grade
# 295  Student296     68.0   41.0   89.0     64.0            82.0  344.0     D
# 296  Student297     68.0   96.0   82.0     36.0            81.0  363.0     C
# 297  Student298     45.0   47.0   46.0    100.0            57.0  295.0     F
# 298  Student299     97.0  100.0   76.0     97.0            61.0  431.0     B
# 299  Student300     88.0   41.0   64.0     41.0            87.0  321.0     D

# %%
print(df.isnull().sum())
# Out:
# Name               0
# English           10
# Tamil             10
# Maths              8
# Science            5
# Social_Science    13
# Total              1
# Grade              0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
print(df.isnull().sum())
print(df.head(10))
# Out:
# Name              0
# English           0
# Tamil             0
# Maths             0
# Science           0
# Social_Science    0
# Total             0
# Grade             0
# dtype: int64
#         Name   English  Tamil  Maths    Science  Social_Science  Total Grade
# 0   Student1  50.00000   47.0   68.0  91.000000       68.602787  324.0     D
# 1   Student2  40.00000   72.0   94.0  45.000000       53.000000  304.0     D
# 2   Student3  78.00000   61.0   58.0  95.000000       75.000000  367.0     C
# 3   Student4  68.02069   95.0   50.0  80.000000       40.000000  340.0     D
# 4   Student5  69.00000   58.0   54.0  74.000000       94.000000  349.0     D
# 5   Student6  84.00000   42.0   61.0  76.000000       52.000000  315.0     D
# 6   Student7  48.00000   36.0   67.0  48.000000       72.000000  271.0     F
# 7   Student8  54.00000   40.0   43.0  57.000000       51.000000  245.0     F
# 8   Student9  68.02069   77.0   95.0  74.000000       91.000000  389.0     C
# ...
