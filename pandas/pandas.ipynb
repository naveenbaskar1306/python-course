# %%
import pandas as pd

df = pd.read_csv("student.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("student.csv")
#       4 print(df)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print(df.head())
# Out:
#        Name  English  Tamil  Maths  Science  Social_Science  Total Grade
# 0  Student1       50     47     68       91              68    324     D
# 1  Student2       40     72     94       45              53    304     D
# 2  Student3       78     61     58       95              75    367     C
# 3  Student4       75     95     50       80              40    340     D
# 4  Student5       69     58     54       74              94    349     D

# %%
print(df.tail())
# Out:
#            Name  English  Tamil  Maths  Science  Social_Science  Total Grade
# 295  Student296       68     41     89       64              82    344     D
# 296  Student297       68     96     82       36              81    363     C
# 297  Student298       45     47     46      100              57    295     F
# 298  Student299       97    100     76       97              61    431     B
# 299  Student300       88     41     64       41              87    321     D

# %%
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
+
