# %%
d = {"abc": 123, "BCD": 256}

while True:
    search = input("Enter the value (or type quit): ")

    if search == "quit":
        break

    if search in d:
        print(d[search])
    else:
        print("Not found")
# Out:
# 123
# Not found
