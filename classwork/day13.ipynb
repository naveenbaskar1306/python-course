# %%
class object:
    def add(self):
        a=int(input("enter the value"))
        b=int(input("enter the value"))
        c=a+b
        return c
    def sub():
        c=a-b
        return c
op=object()
op.add()
# Out:
# 30
