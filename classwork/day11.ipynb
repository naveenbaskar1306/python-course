# %%
try:
    a=int(input("Enter value for a"))
    b=int(input("Enter value for b"))
    c=a/b
    print("a/b=%d"%c)
except Exception:
    print("We can not divide by zero")
else:
    print("We can divide by zero")
# Out:
# a/b=0
# We can divide by zero

# %%
try:
    age=int(input("Enter person's age"))
    if age<60:
        raise ValueError;
    else:
        print("person is qualified for senior citizenship")
except ValueError:
        print("person is not qualified for senior citizenship")
# Out:
# person is qualified for senior citizenship

# %%
def myfunction():
    print(8+2)
    print(7+3)

myfunction()
# Out:
# 10
# 10

# %%
k = 10
d = k // 2

for i in range(d, k+1):
    j = k - i
    print(i,"+", j)
# Out:
# 5 + 5
# 6 + 4
# 7 + 3
# 8 + 2
# 9 + 1
# 10 + 0
