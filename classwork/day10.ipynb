# %%
l1=["apple","banana","cherry"]
l2=[1,2,3]
d = dic(zip(l1,l2))
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 l1=["apple","banana","cherry"]
#       2 l2=[1,2,3]
# ----> 3 d = dic(zip(l1,l2))
#       4 print(d)
#
# NameError: name 'dic' is not defined
