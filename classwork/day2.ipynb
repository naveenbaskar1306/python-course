# %%
k="hi"
print(type(k))
print( k)
# Out:
# <class 'str'>
# hi

# %%
k = 29
print(type(k))
# Out:
# <class 'int'>

# %%
k=True
print(type(k))
# Out:
# <class 'bool'>

# %%
k=1+9j
print(type(k))
# Out:
# <class 'complex'>

# %%
k=10.5
print(type(k))
# Out:
# <class 'float'>

# %%
k1=1+56j
print(k1)
# Out:
# (1+56j)
