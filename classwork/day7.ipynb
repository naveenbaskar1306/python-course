# %%
s1={"hi","hello",5,6,7,8}
s2={2,3,4,5}
s1.remove("hello")
print(s1)
s1.add("hey")
print(s1)
s3=s1.union(s2)
print(s3)
# Out:
# {5, 6, 7, 8, 'hi'}
# {5, 6, 7, 8, 'hey', 'hi'}
# {2, 3, 4, 5, 6, 7, 8, 'hey', 'hi'}
