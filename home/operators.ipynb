# %%
a=int(input(" enter the number"))
b=int(input("enter the number"))


print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 5
# -1
# 0.6666666666666666
# 6
# 2
# 8

# %%
a=int(input(" enter the number"))
b=a+10
print(b)
# Out:
# 15

# %%
x=5
y=10
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True

# %%
a=10
b=20
if a<b:
 print("correct")
else:
 print("wrong")
# Out:
# correct

# %%
a=10
b=20
print(a+b or a*b)
print(a+b and a-b)
print (not(a+b or a-b))
# Out:
# 30
# -10
# False
