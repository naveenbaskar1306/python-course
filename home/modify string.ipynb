# %%
#Upper Case

a = "Welcome To the world"
print(a.upper())
# Out:
# WELCOME TO THE WORLD

# %%
#Lower Case

a="WELCOME TO THE WORLD"
print(a.lower())
# Out:
# welcome to the world

# %%
#Remove Whitespace
a="   Remove Whitespace  "
print(a.strip())
# Out:
# Remove Whitespace

# %%
#Replace String
a="Replace String"
print(a.replace("h","h"))
# Out:
# Replace String
