# %%
a=10
b=str(a)
print(b)
b=float(a)
print(b)
b=bool(a)
print(b)
b=complex(a)
print(b)
# Out:
# 10
# 10.0
# True
# (10+0j)

# %%
x = {"apple", "banana", "cherry"}
y=list(x)
print(y)
# Out:
# ['cherry', 'apple', 'banana']

# %%
x=range(8)
print(x)
# Out:
# range(0, 8)

# %%
# Out:
# (10+0j)

# %%
b=complex(a)
print(b)
# Out:
# (10+0j)
