# %%
employees = [
    {"name": "a", "id": 101, "salary": 50000},
    {"name": "b", "id": 102, "salary": 60000},
    {"name": "c", "id": 103, "salary": 55000},
    {"name": "d", "id": 104, "salary": 70000},
    {"name": "e", "id": 105, "salary": 48000},
    {"name": "f", "id": 106, "salary": 75000},
    {"name": "h", "id": 107, "salary": 52000},
    {"name": "i", "id": 108, "salary": 68000},
    {"name": "j", "id": 109, "salary": 59000},
    {"name": "k", "id": 110, "salary": 72000}
]

user = int(input("Enter Employee ID: "))

if user == employees[0]["id"]:
    print(employees[0])
elif user == employees[1]["id"]:
    print(employees[1])
elif user == employees[2]["id"]:
    print(employees[2])
elif user == employees[3]["id"]:
    print(employees[3])
elif user == employees[4]["id"]:
    print(employees[4])
elif user == employees[5]["id"]:
    print(employees[5])
elif user == employees[6]["id"]:
    print(employees[6])
elif user == employees[7]["id"]:
    print(employees[7])
elif user == employees[8]["id"]:
    print(employees[8])
elif user == employees[9]["id"]:
    print(employees[9])
else:
    print("Employee not found")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 employees = {
#       2     {"name": "a", "id": 101, "salary": 50000},
#       3     {"name": "b", "id": 102, "salary": 60000},
#       4     {"name": "c", "id": 103, "salary": 55000},
#       5     {"name": "d", "id": 104, "salary": 70000},
#       6     {"name": "e", "id": 105, "salary": 48000},
#       7     {"name": "f", "id": 106, "salary": 75000},
#       8     {"name": "h", "id": 107, "salary": 52000},
#       9     {"name": "i", "id": 108, "salary": 68000},
#      10     {"name": "j", "id": 109, "salary": 59000},
#      11     {"name": "k", "id": 110, "salary": 72000}
#      12 }
#      14 user = int(input("Enter Employee ID: "))
#      16 if user == employees[0]["id"]:
#
# TypeError: unhashable type: 'dict'
