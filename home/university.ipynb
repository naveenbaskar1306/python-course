# %%
class University:
    def __init__(self, university_name):
        self.university_name = university_name

    def show_university(self):
        print("University Name:", self.university_name)



class College(University):
    def __init__(self, university_name, college_name):
        super().__init__(university_name)
        self.college_name = college_name

    def show_college(self):
        print("College Name:", self.college_name)



class Department(College):
    def __init__(self, university_name, college_name, department_name):
        super().__init__(university_name, college_name)
        self.department_name = department_name

    def show_department(self):
        print("Department Name:", self.department_name)


dept = Department(
    "Anna University",
    "XYZ Engineering College",
    "Computer Science"
)


dept.show_university()
dept.show_college()
dept.show_department()
