# %%
company=["infosys","cognizant","wipro","tcs"]
location=["chennai","cbe","banglore"]
c= input("Enter the company").lower()
l= input("Enter the location").lower()
a= input("enter your language")
b=input("enter the experience")
if c in company and l in location:
    print("available")
else:
    print(" Not available")
if a =="java" :
    print("java")
elif a=="python" :
    print("python")
else:
    print(" Not available")
if b=="fresher":
    print("fresher")
elif b=="experince":
    print("experince")
else:
    print(" Not available")
# Out:
# available
# java
#  Not available
