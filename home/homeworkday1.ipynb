# %%
##  legal variables

# %%
number = 1
num_ber = 1
_num_ber =1
nuMbEr =1
NUMBER =1
NUMBER1 =1

print(number)
print(num_ber)
print(_num_ber)
print(nuMbEr)
# Out:
# 1
# 1
# 1
# 1

# %%
## Illegal variable names

# %%
1number =1
num-ber =1
my var =1
@my var=1m

print(1number)
# Out:
#   Cell In[8], line 1
#     1number =1
#     ^
# SyntaxError: invalid decimal literal

# %%
a = int(input("Enter value for a:"))  
b = int(input("Enter value for b:"))
c = int(input("Enter value for c:"))  
d = int(input("Enter value for d:"))
e = a+b+c+d;
f = a-b-c-d;
g = a*b*c*d;
h = a/b/c/d;  
print("Addition of a,b,c,d is = %d"%e)
print("Subtraction of a,b,c,d is = %d"%f)
print("Multiplication of a,b,c,d is = %d"%g)
print("Divsion of a,b,c,d is = %d"%h)
print(e)
print(f)
print(g)
print(h)
# Out:
# Addition of a,b,c,d is = 100
# Subtraction of a,b,c,d is = -80
# Multiplication of a,b,c,d is = 240000
# Divsion of a,b,c,d is = 0
# 100
# -80
# 240000
# 0.00041666666666666664
